# %% [markdown]
# # Convolutional Neural Networks (CNNs)
#
# Learning objectives, executive summary, and CNN overview.

# %% [markdown]
# ## Why Fully Connected Networks Fail on Images
#
# Parameter explosion and loss of spatial information.

# %% [markdown]
# ## Convolution Operation
#
# Mathematics and intuition behind kernels and filters.

# %% [markdown]
# ## Kernel Visualization

# %% [markdown]
# ## Feature Maps
#
# Hierarchical feature learning.

# %% [markdown]
# ## Pooling Layers
#
# Max pooling and average pooling.

# %% [markdown]
# ## CNN Architecture
#
# Input → Conv → ReLU → Pool → Dense → Output

# %% [markdown]
# ## TensorFlow CNN on MNIST
#
# End-to-end TensorFlow example.

# %% [markdown]
# ## PyTorch CNN
#
# Equivalent PyTorch architecture.

# %% [markdown]
# ## Data Augmentation
#
# Improving generalization.

# %% [markdown]
# ## Transfer Learning with ResNet50
#
# Using pretrained models.

# %% [markdown]
# ## Experiments
#
# Kernel size, pooling, architecture depth.

# %% [markdown]
# ## Case Studies
#
# Face recognition, medical imaging, autonomous vehicles.

# %% [markdown]
# ## Interview Questions
#
# Beginner to advanced.

# %% [markdown]
# ## Research Insights
#
# ViT, ConvNeXt, EfficientNet.

# %% [markdown]
# ## Mini Project
#
# Cats vs Dogs classification.

# %% [markdown]
# ## Summary
#
# Key takeaways.

# %%
image_size = 224*224*3
print("Input Features:", image_size)
print("Parameters for 100 neurons:", image_size*100)

# %%
import numpy as np
image=np.array([[1,2,3,0],[0,1,2,3],[3,0,1,2],[2,3,0,1]])
kernel=np.array([[1,0],[0,-1]])
out=np.zeros((3,3))
for i in range(3):
    for j in range(3):
        out[i,j]=np.sum(image[i:i+2,j:j+2]*kernel)
print(out)

# %%
import numpy as np, matplotlib.pyplot as plt
kernel=np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
plt.imshow(kernel,cmap='gray')
plt.title('Edge Detection Kernel')
plt.colorbar()
plt.show()

# %%
import numpy as np
feature_map=np.array([[1,3,2,1],[4,6,5,2],[7,2,8,3],[1,4,2,5]])
pooled=np.array([[np.max(feature_map[0:2,0:2]),np.max(feature_map[0:2,2:4])],
                 [np.max(feature_map[2:4,0:2]),np.max(feature_map[2:4,2:4])]])
print(pooled)

# %%
# TensorFlow CNN (run if TensorFlow installed)
import tensorflow as tf
model=tf.keras.Sequential([
 tf.keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)),
 tf.keras.layers.MaxPooling2D((2,2)),
 tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
 tf.keras.layers.MaxPooling2D((2,2)),
 tf.keras.layers.Flatten(),
 tf.keras.layers.Dense(128,activation='relu'),
 tf.keras.layers.Dense(10,activation='softmax')
])
model.summary()

# %%
# PyTorch CNN
import torch
import torch.nn as nn
class CNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1=nn.Conv2d(1,32,3)
        self.pool=nn.MaxPool2d(2)
        self.conv2=nn.Conv2d(32,64,3)
        self.fc1=nn.Linear(1600,128)
        self.fc2=nn.Linear(128,10)
    def forward(self,x):
        x=torch.relu(self.conv1(x))
        x=self.pool(x)
        x=torch.relu(self.conv2(x))
        x=self.pool(x)
        x=x.view(x.size(0),-1)
        x=torch.relu(self.fc1(x))
        return self.fc2(x)
print(CNN())

# %%
# Transfer Learning
from tensorflow.keras.applications import ResNet50
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(224,224,3))
print('ResNet50 loaded')
