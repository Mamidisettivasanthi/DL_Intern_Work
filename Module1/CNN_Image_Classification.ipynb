# %% [markdown]
# # Convolutional Neural Networks (CNNs)
# Comprehensive CNN notebook.

# %% [markdown]
# ## Why Fully Connected Networks Fail on Images

# %%
image_size=224*224*3
print(image_size*100)

# %% [markdown]
# ## Convolution Operation

# %%
import numpy as np
image=np.array([[1,2],[3,4]])
kernel=np.array([[1,0],[0,-1]])
print(np.sum(image*kernel))

# %% [markdown]
# ## Pooling Layers

# %%
import numpy as np
x=np.array([[1,2],[3,4]])
print(np.max(x))

# %% [markdown]
# ## TensorFlow CNN Example

# %%
import tensorflow as tf
print(tf.__version__)

# %% [markdown]
# ## PyTorch CNN Example

# %%
import torch
print(torch.__version__)

# %% [markdown]
# ## Transfer Learning with ResNet50

# %% [markdown]
# ## Experiments, Case Studies, Interview Questions, Research Insights, Mini Project
